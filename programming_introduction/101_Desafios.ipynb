# %%
# Desconsidere estas linhas para o estudo da disciplina

from IPython.display import Image, YouTubeVideo

# %% [markdown]
# # Desafios
#
# Desafios são atividades mais elaboradas e que exigem um conhecimento mais completo dos assuntos vistos em sala de aula.

# %% [markdown]
# ## Desafio 1
#
# **01)** Implemente uma versão simples deste jogo: https://pt.wikipedia.org/wiki/Pedra-papel-tesoura-lagarto-Spock

# %%
YouTubeVideo("abQj0pQkSOY")
